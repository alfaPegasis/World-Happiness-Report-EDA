# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/world-happiness-report-2021/world-happiness-report-2021.csv
# /kaggle/input/world-happiness-report-2021/world-happiness-report.csv

# %%
df=pd.read_csv('../input/world-happiness-report-2021/world-happiness-report-2021.csv')
df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
df.dtypes
# Out:
# Country name                                   object
# Regional indicator                             object
# Ladder score                                  float64
# Standard error of ladder score                float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Logged GDP per capita                         float64
# Social support                                float64
# Healthy life expectancy                       float64
# Freedom to make life choices                  float64
# Generosity                                    float64
# Perceptions of corruption                     float64
# Ladder score in Dystopia                      float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# ...

# %%
a=df[df['Country name']=='India']
a
# Out:
#     Country name Regional indicator  Ladder score  \
# 138        India         South Asia         3.819
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 138                           0.026         3.869         3.769
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 138                  8.755           0.603                   60.633
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 138                         0.893       0.089                      0.774
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 138                      2.43                             0.741
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 138                         0.316                                  0.383
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 138                                       0.622                     0.246
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")

# %% [markdown]
# # Score of Different regions of the World

# %%
plt.figure(figsize=(15,8))
sns.barplot(y='Regional indicator',x='Ladder score',data=df,palette="Blues_d",ci=0).set_title("Region-wise Score")
plt.show()

# %% [markdown]
# # Region-wise plot for Freedom vs Ladder score

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x="Ladder score",y="Freedom to make life choices",data=df,hue='Regional indicator')
plt.show()

# %% [markdown]
# # How Social Support impacts Score of the country?

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x="Ladder score",y="Social support",data=df)
plt.show()

# %% [markdown]
# # Higher the GDP per capita, Higher the score

# %%
plt.figure(figsize=(15,8))
sns.jointplot(x="Ladder score",y="Logged GDP per capita",data=df,kind='hex')
plt.show()

# %% [markdown]
# # Perception of corruption of various regions of the world

# %%
plt.figure(figsize=(15,8))
#sns.displot(data=df,y='Perceptions of corruption',x='Ladder score')
sns.barplot(data=df,x='Perceptions of corruption',y='Regional indicator',ci=0)
plt.show()

# %% [markdown]
# # Have a look at more interactive charts

# %%
import plotly.express as px

# %%
px.scatter(data_frame=df,x='Ladder score', y='Logged GDP per capita', hover_name='Country name')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
plt.figure(figsize=(30,10))
px.sunburst(data_frame=df, path=['Regional indicator','Country name'], values='Ladder score')
# Out:
# <div>                            <div id="2ca7c84a-c486-4c68-a45c-1ea5134daf85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ca7c84a-c486-4c68-a45c-1ea5134daf85")) {                    Plotly.newPlot(                        "2ca7c84a-c486-4c68-a45c-1ea5134daf85",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Ladder score=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["South Asia/Afghanistan", "Central and Eastern Europe/Albania", "Middle East and North Africa/Algeria", "Latin America and Caribbean/Argentina", "Commonwealth of Independent States/Armenia", "North America and ANZ/Australia", "Western Europe/Austria", "Commonwealth of Independen
# ...
